# %%
#read the information of A2-ring-merged.txt and load it into a dataframe to plot it
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read A2 ring merged data  
df_merged = pd.read_csv('Data/A2-ring/A2-ring-merged.txt', sep='\t', header=None)
print(df_merged.shape[0])
print(df_merged[df_merged.columns[0]])

#read two input(features) columns
x = df_merged[df_merged.columns[0]]
y = df_merged[df_merged.columns[1]]

#read one output(class) column
output = df_merged[df_merged.columns[2]]
sizes = np.full((1, df_merged.shape[0]), 1)

# Create a scatter plot using Matplotlib
scatter = plt.scatter(x, y, c=output, s=sizes)

# Set labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot of A2-ring-merged')

# Create a legend using the scatter points and class labels
legend = plt.legend(*scatter.legend_elements(), title='Classes')
# Display the plot
plt.show()
# Out:
# 10000
# 0      -0.137094
# 1       0.542574
# 2      -0.658204
# 3      -0.869820
# 4       0.678610
#           ...
# 9995    0.419610
# 9996   -0.456348
# 9997   -0.003036
# 9998    0.765332
# 9999   -0.532259
# Name: 0, Length: 10000, dtype: float64

# %%
#read the information of A2-ring-separable.txt and load it into a dataframe to plot it
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read A2 ring merged data  
df_separable = pd.read_csv('Data/A2-ring/A2-ring-separable.txt', sep='\t', header=None)
print(df_separable.shape[0])
print(df_separable[df_separable.columns[0]])

#read two input(features) columns
x = df_separable[df_separable.columns[0]]
y = df_separable[df_separable.columns[1]]

#read one output(class) column
output = df_separable[df_separable.columns[2]]
sizes = np.full((1, df_separable.shape[0]), 1)

# Create a scatter plot using Matplotlib
scatter = plt.scatter(x, y, c=output, s=sizes)

# Set labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot of A2-ring-separable')

# Create a legend using the scatter points and class labels
legend = plt.legend(*scatter.legend_elements(), title='Classes')
# Display the plot
plt.show()
# Out:
# 10000
# 0      -0.137094
# 1       0.542574
# 2      -0.658204
# 3      -0.869820
# 4       0.678610
#           ...
# 9995    0.419610
# 9996   -0.456348
# 9997   -0.003036
# 9998    0.765332
# 9999   -0.532259
# Name: 0, Length: 10000, dtype: float64

# %%
#read the information of A2-ring-test.txt and load it into a dataframe to plot it
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read A2 ring test data  
df_test = pd.read_csv('Data/A2-ring/A2-ring-test.txt', sep='\t', header=None)
print(df_test.shape[0])
print(df_test[df_test.columns[0]])

#read two input(features) columns
x = df_test[df_test.columns[0]]
y = df_test[df_test.columns[1]]

#read one output(class) column
output = df_test[df_test.columns[2]]
sizes = np.full((1, df_test.shape[0]), 1)

# Create a scatter plot using Matplotlib
scatter = plt.scatter(x, y, c=output, s=sizes)

# Set labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot of A2-ring-test')

# Create a legend using the scatter points and class labels
legend = plt.legend(*scatter.legend_elements(), title='Classes')
# Display the plot
plt.show()
# Out:
# 10000
# 0       0.512196
# 1       0.610173
# 2       0.927970
# 3       0.159933
# 4      -0.451556
#           ...
# 9995    0.958078
# 9996    0.544659
# 9997   -0.684583
# 9998    0.906773
# 9999   -0.544859
# Name: 0, Length: 10000, dtype: float64
